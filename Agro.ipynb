# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Ler Base Dados

# %%
filepath = 'Data/Precos_de_Casas/train.csv'
data = pd.read_csv(filepath, sep = ',')
#data=data.dropna()
# imprima a dimensão da base
print(f'(Linhas, Colunas): {data.shape}')
# Out:
# (Linhas, Colunas): (1460, 81)

# %%
data=data[['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']]

# %%
LotFrontage  MasVnrArea  GarageYrBlt
# Out:
#   File "<ipython-input-112-01450ab4cdaf>", line 1
#     LotFrontage  MasVnrArea  GarageYrBlt
#                           ^
# SyntaxError: invalid syntax

# %%
print (data.Alley.value_counts())
print (data.FireplaceQu.value_counts())
print (data.PoolQC.value_counts())
print (data.Fence.value_counts())
print (data.MiscFeature.value_counts())
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# Gd    3
# Ex    2
# Fa    2
# Name: PoolQC, dtype: int64
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
# Shed    49
# Othr     2
# Gar2     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 0        1          60       RL     8450   Pave   NaN      Reg         Lvl
# 1        2          20       RL     9600   Pave   NaN      Reg         Lvl
# 2        3          60       RL    11250   Pave   NaN      IR1         Lvl
# 3        4          70       RL     9550   Pave   NaN      IR1         Lvl
# 4        5          60       RL    14260   Pave   NaN      IR1         Lvl
# 5        6          50       RL    14115   Pave   NaN      IR1         Lvl
# 6        7          20       RL    10084   Pave   NaN      Reg         Lvl
# 7        8          60       RL    10382   Pave   NaN      IR1         Lvl
# 8        9          50       RM     6120   Pave   NaN      Reg         Lvl
# 9       10         190       RL     7420   Pave   NaN      Reg         Lvl
# 10      11          20       RL    11200   Pave   NaN      Reg         Lvl
# 11      12          60       RL    11924   Pave   NaN      IR1         Lvl
# 12      13          20       RL    12968   Pave   NaN      IR2         Lvl
# 13      14          20       RL    10652   Pave   NaN      IR1         Lvl
# 14      15          20       RL    10920   Pave   NaN      IR1         Lvl
# 15      16          45       RM     6120   Pave   NaN      Reg         Lvl
# 16      17          20       RL    11241   Pave   NaN      IR1         Lvl
# 17      18          90       RL    10791   Pave   NaN      Reg         Lvl
# 18      19          20       RL    13695   Pave   NaN      Reg         Lvl
# 19      20          20       RL     7560   Pave   NaN      Reg         Lvl
# 20      21          60       RL    14215   Pave   NaN      IR1         Lvl
# 21      22          45       RM     7449   Pave  Grvl      Reg         Bnk
# 22      23          20       RL     9742   Pave   NaN      Reg         Lvl
# 23      24         120       RM     4224   Pave   NaN      Reg         Lvl
# 24      25          20       RL     8246   Pave   NaN      IR1         Lvl
# 25      26          20       RL    14230   Pave   NaN      Reg         Lvl
# 26      27          20       RL     7200   Pave   NaN      Reg         Lvl
# 27      28          20       RL    11478   Pave   NaN      Reg         Lvl
# 28      29          20       RL    16321   Pave   NaN      IR1         Lvl
# 29      30          30       RM     6324   Pave   NaN      IR1         Lvl
# ...    ...         ...      ...      ...    ...   ...      ...         ...
# 1430  1431          60       RL    21930   Pave   NaN      IR3         Lvl
# 1431  1432         120       RL     4928   Pave   NaN      IR1         Lvl
# 1432  1433          30       RL    10800   Pave  Grvl      Reg         Lvl
# 1433  1434          60       RL    10261   Pave   NaN      IR1         Lvl
# 1434  1435          20       RL    17400   Pave   NaN      Reg         Low
# 1435  1436          20       RL     8400   Pave   NaN      Reg         Lvl
# 1436  1437          20       RL     9000   Pave   NaN      Reg         Lvl
# 1437  1438          20       RL    12444   Pave   NaN      Reg         Lvl
# 1438  1439          20       RM     7407   Pave   NaN      Reg         Lvl
# 1439  1440          60       RL    11584   Pave   NaN      Reg         Lvl
# 1440  1441          70       RL    11526   Pave   NaN      IR1         Bnk
# 1441  1442         120       RM     4426   Pave   NaN      Reg         Lvl
# 1442  1443          60       FV    11003   Pave   NaN      Reg         Lvl
# 1443  1444          30       RL     8854   Pave   NaN      Reg         Lvl
# 1444  1445          20       RL     8500   Pave   NaN      Reg         Lvl
# 1445  1446          85       RL     8400   Pave   NaN      Reg         Lvl
# 1446  1447          20       RL    26142   Pave   NaN      IR1         Lvl
# 1447  1448          60       RL    10000   Pave   NaN      Reg         Lvl
# 1448  1449          50       RL    11767   Pave   NaN      Reg         Lvl
# 1449  1450         180       RM     1533   Pave   NaN      Reg         Lvl
# 1450  1451          90       RL     9000   Pave   NaN      Reg         Lvl
# 1451  1452          20       RL     9262   Pave   NaN      Reg         Lvl
# 1452  1453         180       RM     3675   Pave   NaN      Reg         Lvl
# 1453  1454          20       RL    17217   Pave   NaN      Reg         Lvl
# 1454  1455          20       FV     7500   Pave  Pave      Reg         Lvl
# 1455  1456          60       RL     7917   Pave   NaN      Reg         Lvl
# 1456  1457          20       RL    13175   Pave   NaN      Reg         Lvl
# 1457  1458          70       RL     9042   Pave   NaN      Reg         Lvl
# 1458  1459          20       RL     9717   Pave   NaN      Reg         Lvl
# 1459  1460          20       RL     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig    ...     PoolArea PoolQC  Fence MiscFeature  \
# 0       AllPub    Inside    ...            0    NaN    NaN         NaN
# 1       AllPub       FR2    ...            0    NaN    NaN         NaN
# 2       AllPub    Inside    ...            0    NaN    NaN         NaN
# 3       AllPub    Corner    ...            0    NaN    NaN         NaN
# 4       AllPub       FR2    ...            0    NaN    NaN         NaN
# 5       AllPub    Inside    ...            0    NaN  MnPrv        Shed
# 6       AllPub    Inside    ...            0    NaN    NaN         NaN
# 7       AllPub    Corner    ...            0    NaN    NaN        Shed
# 8       AllPub    Inside    ...            0    NaN    NaN         NaN
# 9       AllPub    Corner    ...            0    NaN    NaN         NaN
# 10      AllPub    Inside    ...            0    NaN    NaN         NaN
# 11      AllPub    Inside    ...            0    NaN    NaN         NaN
# 12      AllPub    Inside    ...            0    NaN    NaN         NaN
# 13      AllPub    Inside    ...            0    NaN    NaN         NaN
# 14      AllPub    Corner    ...            0    NaN   GdWo         NaN
# 15      AllPub    Corner    ...            0    NaN  GdPrv         NaN
# 16      AllPub   CulDSac    ...            0    NaN    NaN        Shed
# 17      AllPub    Inside    ...            0    NaN    NaN        Shed
# 18      AllPub    Inside    ...            0    NaN    NaN         NaN
# 19      AllPub    Inside    ...            0    NaN  MnPrv         NaN
# 20      AllPub    Corner    ...            0    NaN    NaN         NaN
# 21      AllPub    Inside    ...            0    NaN  GdPrv         NaN
# 22      AllPub    Inside    ...            0    NaN    NaN         NaN
# 23      AllPub    Inside    ...            0    NaN    NaN         NaN
# 24      AllPub    Inside    ...            0    NaN  MnPrv         NaN
# 25      AllPub    Corner    ...            0    NaN    NaN         NaN
# 26      AllPub    Corner    ...            0    NaN    NaN         NaN
# 27      AllPub    Inside    ...            0    NaN    NaN         NaN
# 28      AllPub   CulDSac    ...            0    NaN    NaN         NaN
# 29      AllPub    Inside    ...            0    NaN    NaN         NaN
# ...        ...       ...    ...          ...    ...    ...         ...
# 1430    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1431    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1432    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1433    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1434    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1435    AllPub    Inside    ...            0    NaN  GdPrv         NaN
# 1436    AllPub       FR2    ...            0    NaN   GdWo         NaN
# 1437    AllPub       FR2    ...            0    NaN    NaN         NaN
# 1438    AllPub    Inside    ...            0    NaN  MnPrv         NaN
# 1439    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1440    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1441    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1442    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1443    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1444    AllPub       FR2    ...            0    NaN    NaN         NaN
# 1445    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1446    AllPub   CulDSac    ...            0    NaN    NaN         NaN
# 1447    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1448    AllPub    Inside    ...            0    NaN   GdWo         NaN
# 1449    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1450    AllPub       FR2    ...            0    NaN    NaN         NaN
# 1451    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1452    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1453    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1454    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1455    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1456    AllPub    Inside    ...            0    NaN  MnPrv         NaN
# 1457    AllPub    Inside    ...            0    NaN  GdPrv        Shed
# 1458    AllPub    Inside    ...            0    NaN    NaN         NaN
# 1459    AllPub    Inside    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0          0      2    2008        WD         Normal     208500
# 1          0      5    2007        WD         Normal     181500
# 2          0      9    2008        WD         Normal     223500
# 3          0      2    2006        WD        Abnorml     140000
# 4          0     12    2008        WD         Normal     250000
# 5        700     10    2009        WD         Normal     143000
# 6          0      8    2007        WD         Normal     307000
# 7        350     11    2009        WD         Normal     200000
# 8          0      4    2008        WD        Abnorml     129900
# 9          0      1    2008        WD         Normal     118000
# 10         0      2    2008        WD         Normal     129500
# 11         0      7    2006       New        Partial     345000
# 12         0      9    2008        WD         Normal     144000
# 13         0      8    2007       New        Partial     279500
# 14         0      5    2008        WD         Normal     157000
# 15         0      7    2007        WD         Normal     132000
# 16       700      3    2010        WD         Normal     149000
# 17       500     10    2006        WD         Normal      90000
# 18         0      6    2008        WD         Normal     159000
# 19         0      5    2009       COD        Abnorml     139000
# 20         0     11    2006       New        Partial     325300
# 21         0      6    2007        WD         Normal     139400
# 22         0      9    2008        WD         Normal     230000
# 23         0      6    2007        WD         Normal     129900
# 24         0      5    2010        WD         Normal     154000
# 25         0      7    2009        WD         Normal     256300
# 26         0      5    2010        WD         Normal     134800
# 27         0      5    2010        WD         Normal     306000
# 28         0     12    2006        WD         Normal     207500
# 29         0      5    2008        WD         Normal      68500
# ...      ...    ...     ...       ...            ...        ...
# 1430       0      7    2006        WD         Normal     192140
# 1431       0     10    2009        WD         Normal     143750
# 1432       0      8    2007        WD         Normal      64500
# 1433       0      5    2008        WD         Normal     186500
# 1434       0      5    2006        WD         Normal     160000
# 1435       0      7    2008       COD        Abnorml     174000
# 1436       0      5    2007        WD         Normal     120500
# 1437       0     11    2008       New        Partial     394617
# 1438       0      4    2010        WD         Normal     149700
# 1439       0     11    2007        WD         Normal     197000
# 1440       0      9    2008        WD         Normal     191000
# 1441       0      5    2008        WD         Normal     149300
# 1442       0      4    2009        WD         Normal     310000
# 1443       0      5    2009        WD         Normal     121000
# 1444       0     11    2007        WD         Normal     179600
# 1445       0      5    2007        WD         Normal     129000
# 1446       0      4    2010        WD         Normal     157900
# 1447       0     12    2007        WD         Normal     240000
# 1448       0      5    2007        WD         Normal     112000
# 1449       0      8    2006        WD        Abnorml      92000
# 1450       0      9    2009        WD         Normal     136000
# 1451       0      5    2009       New        Partial     287090
# 1452       0      5    2006        WD         Normal     145000
# 1453       0      7    2006        WD        Abnorml      84500
# 1454       0     10    2009        WD         Normal     185000
# 1455       0      8    2007        WD         Normal     175000
# 1456       0      2    2010        WD         Normal     210000
# 1457    2500      5    2010        WD         Normal     266500
# 1458       0      4    2010        WD         Normal     142125
# 1459       0      6    2008        WD         Normal     147500
#
# [1460 rows x 78 columns]

# %% [markdown]
# ## Analises Exploratoria

# %%
# Use o método value_counts() no atributo dtypes
data.dtypes.value_counts()
# Out:
# object    43
# int64     35
# dtype: int64

# %% [markdown]
# ## Tratamento dos Dados

# %% [markdown]
# ###### Analizando as Variaveis Categoricas

# %%
# Selecione apenas os tipos object
mask = data.dtypes == np.object
categorical_cols = data.columns[mask]

# Usei o loop abaixo para predizer o valor que eu precisaria atingir antes de implementar as transformações
# column_counter = 0
# for column in categorical_cols:
#     column_counter += (len(data[column].value_counts()) - 1)

# print("Quantidade maxima de Colunas que poderiam se encrementar: "+str(column_counter))
categorical_cols
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# quantidade de valores distintos das variaveis categoricas
num_ohc_cols = data[categorical_cols].apply(pd.Series.nunique).sort_values()
num_ohc_cols
# Out:
# Street            2
# Alley             2
# CentralAir        2
# Utilities         2
# LandSlope         3
# PoolQC            3
# PavedDrive        3
# GarageFinish      3
# BsmtQual          4
# ExterQual         4
# MasVnrType        4
# KitchenQual       4
# BsmtCond          4
# BsmtExposure      4
# Fence             4
# MiscFeature       4
# LandContour       4
# LotShape          4
# FireplaceQu       5
# Electrical        5
# HeatingQC         5
# GarageQual        5
# GarageCond        5
# MSZoning          5
# LotConfig         5
# BldgType          5
# ExterCond         5
# BsmtFinType1      6
# RoofStyle         6
# GarageType        6
# Foundation        6
# Heating           6
# BsmtFinType2      6
# SaleCondition     6
# Functional        7
# RoofMatl          8
# HouseStyle        8
# Condition2        8
# SaleType          9
# Condition1        9
# Exterior1st      15
# Exterior2nd      16
# Neighborhood     25
# dtype: int64

# %%
# Eliminando as colunas categoricas com apenas 1 valor categórico 
filtered_num_ohc_cols = num_ohc_cols[num_ohc_cols.values > 1]
print ("Lista de Variaveis com mais de um valor categorico")
print(filtered_num_ohc_cols)
# Substraindo em um os valores anteriores
filtered_num_ohc_cols -= 1
# SUmando os valores das variaveis categoricas
print("Quantidade de Variaveis a ser criadas: "+str(filtered_num_ohc_cols.sum()))
# Out:
# Lista de Variaveis com mais de um valor categorico
# Street            2
# Alley             2
# CentralAir        2
# Utilities         2
# LandSlope         3
# PoolQC            3
# PavedDrive        3
# GarageFinish      3
# BsmtQual          4
# ExterQual         4
# MasVnrType        4
# KitchenQual       4
# BsmtCond          4
# BsmtExposure      4
# Fence             4
# MiscFeature       4
# LandContour       4
# LotShape          4
# FireplaceQu       5
# Electrical        5
# HeatingQC         5
# GarageQual        5
# GarageCond        5
# MSZoning          5
# LotConfig         5
# BldgType          5
# ExterCond         5
# BsmtFinType1      6
# RoofStyle         6
# GarageType        6
# Foundation        6
# Heating           6
# BsmtFinType2      6
# SaleCondition     6
# Functional        7
# RoofMatl          8
# HouseStyle        8
# Condition2        8
# SaleType          9
# Condition1        9
# Exterior1st      15
# Exterior2nd      16
# Neighborhood     25
# dtype: int64
# Quantidade de Variaveis a ser criadas: 209

# %% [markdown]
# ###### Variaveis Categoricas --> binarizados (Metodo ONE-HOT-ENCODING)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# Copiaando o dataframe para outro Variavel
data_ohc = data.copy()

# codificando
le = LabelEncoder()
ohc = OneHotEncoder()

# para cada coluna categórica
for col in filtered_num_ohc_cols.index:
    # Aplicando o método .fit_transform do LabelEncoder e especifique .astype(np.int)
    # o reshape faz com que dat seja uma matriz multidimensional com uma coluna (ao invés de um vetor)
    dat = le.fit_transform(data_ohc[col].astype(str)).astype(np.int).reshape(-1, 1)

    # Removendo a coluna col da base de dados
    data_ohc = data_ohc.drop(columns = [col])
    # One hot encode the data--this returns a sparse array
    new_dat = ohc.fit_transform(dat)
    
    # Vamos criar novos nomes de colunas
    n_cols = new_dat.shape[1]
    col_names = ['_'.join([col, str(x)]) for x in range(n_cols)]
    
    # Criando um novo dataframe a partir de new_dat e col_names, utilize o índice de data_ohc
    new_df = pd.DataFrame(data = new_dat.toarray(), columns = col_names)
    # Concatenando data_ohc com new_df
    data_ohc = data_ohc.join(new_df)
    
data_ohc.shape
# Out:
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\emily\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# (1460, 303)

# %%
# Calcule a diferença entre a quantidade de atributos da base original e da base nova
data_ohc.shape[1] - data.shape[1]
# Out:
# 225

# %%
#imprima as dimensões dos dados originais
print(f'Dimensões do dataframe com os dados originais:\n\t(Linhas, Colunas): {data.shape}')

# Remova as colunas categóricas do dataframe original
non_categorical_data = data.drop(columns = categorical_cols)

#imprima as dimensões dos dados originais, sem os atributos categóricos
print(f'Dimensões do dataframe sem os dados categóricos:\n\t(Linhas, Colunas): {non_categorical_data.shape}')
# Out:
# Dimensões do dataframe com os dados originais:
# 	(Linhas, Colunas): (1460, 78)
# Dimensões do dataframe sem os dados categóricos:
# 	(Linhas, Colunas): (1460, 35)

# %%
non_categorical_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## TREINO E TESTE

# %%
from sklearn.model_selection import train_test_split

y_col = 'SalePrice'

# Faça a divisão da base original utilizando test_size=0.3 e random_state=42
feature_cols = [x for x in non_categorical_data.columns if x != y_col]
X_data = non_categorical_data[feature_cols]
y_data = non_categorical_data[y_col]

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size = 0.3, random_state = 42)

# Repita para a base data_ohc
feature_cols_ohc = [x for x in data_ohc.columns if x != y_col]
X_data_ohc = data_ohc[feature_cols_ohc]
y_data_ohc = data_ohc[y_col]

X_train_ohc, X_test_ohc, y_train_ohc, y_test_ohc = train_test_split(X_data_ohc, y_data_ohc, test_size = 0.3, random_state = 42)

# %%
X_train
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 135    136          20    10400            7            6       1970
# 1452  1453         180     3675            5            5       2005
# 762    763          60     8640            7            5       2009
# 932    933          20    11670            9            5       2006
# 435    436          60    10667            7            6       1996
# 629    630          80     9020            6            5       1964
# 1210  1211          60    11218            6            5       1992
# 1118  1119          80    13825            5            6       1958
# 1084  1085          60    13031            6            5       1995
# 158    159          60    12552            7            5       2004
# 967    968          20     7390            5            7       1955
# 1259  1260          20     9750            6            8       1969
# 551    552          20     6000            5            6       1957
# 497    498          50     9120            7            6       1925
# 1031  1032          75    15863            7            3       1920
# 1262  1263          50    11250            4            5       1957
# 1013  1014          30     7200            5            4       1910
# 1311  1312          20     8814            7            5       2005
# 566    567          60    11198            9            5       2005
# 610    611          60    11050            9            5       2000
# 1278  1279          60     9473            8            5       2002
# 1263  1264          70    13515            6            6       1919
# 816    817          20    11425            5            6       1954
# 438    439          30     4280            5            6       1913
# 940    941          90    12640            6            5       1976
# 96      97          20    10264            7            5       1999
# 560    561          20    11341            5            6       1957
# 1182  1183          60    15623           10            5       1996
# 471    472          60    11952            7            6       1977
# 1004  1005         120     3182            7            5       2005
# ...    ...         ...      ...          ...          ...        ...
# 747    748          70    11700            7            7       1880
# 252    253          60     8366            6            5       2004
# 21      22          45     7449            7            7       1930
# 1337  1338          30     4118            4            4       1941
# 459    460          50     7015            5            4       1950
# 1184  1185          20    35133            5            4       1963
# 276    277          20     9196            7            5       2003
# 955    956          90     7136            6            6       1946
# 1215  1216          20     7094            5            5       1966
# 385    386         120     3182            8            5       2004
# 805    806          20    12274            7            5       2008
# 1437  1438          20    12444            8            5       2008
# 343    344         120     8849            9            5       2005
# 769    770          60    53504            8            5       2003
# 1332  1333          20     8877            4            6       1938
# 130    131          60    14200            7            6       1966
# 871    872          60     8750            6            5       1998
# 1123  1124          20     9405            5            9       1947
# 1396  1397          20    57200            5            5       1948
# 87      88         160     3951            6            5       2009
# 330    331          90    10624            5            4       1964
# 1238  1239          20    13072            6            5       2005
# 466    467          20    10628            7            5       1970
# 121    122          50     6060            4            5       1939
# 1044  1045          20     9600            8            5       1981
# 1095  1096          20     9317            6            5       2006
# 1130  1131          50     7804            4            3       1928
# 1294  1295          20     8172            5            7       1955
# 860    861          50     7642            7            8       1918
# 1126  1127         120     3684            7            5       2007
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF   ...    GarageArea  \
# 135           1970           0           0       1304   ...           530
# 1452          2005         547           0          0   ...           525
# 762           2009          24           0        732   ...           614
# 932           2006           0           0       1905   ...           788
# 435           1996         385         344         70   ...           550
# 629           1964         624         336        288   ...           520
# 1210          1992           0           0       1055   ...           462
# 1118          1987           0           0        533   ...           300
# 1084          1996         592           0         99   ...           409
# 158           2005         222           0        769   ...           678
# 967           1955         902           0        196   ...           260
# 1259          1969         602         438         14   ...           460
# 551           1957         308           0        620   ...           288
# 497           1950         329           0        697   ...           240
# 1031          1970         523           0        301   ...           672
# 1262          1989           0           0       1104   ...           304
# 1013          2006         247         465        310   ...           280
# 1311          2007         925           0        349   ...           508
# 566           2007           0           0       1122   ...           656
# 610           2000         904           0        536   ...           736
# 1278          2002         804           0        324   ...           577
# 1263          1950           0           0        764   ...           520
# 816           1954         486           0        522   ...           275
# 438           2002         365           0         75   ...           352
# 940           1976         936         396        396   ...           574
# 96            1999        1162           0        426   ...           472
# 560           1996        1302           0         90   ...           528
# 1182          1996        2096           0        300   ...           813
# 471           1977           0           0        808   ...           534
# 1004          2006          16           0       1330   ...           457
# ...            ...         ...         ...        ...   ...           ...
# 747           2003           0           0       1240   ...           864
# 252           2004           0           0        798   ...           520
# 21            1950           0           0        637   ...           280
# 1337          1950           0           0        693   ...             0
# 459           1950         185           0        524   ...           352
# 1184          1963        1159           0        413   ...           995
# 276           2003           0           0       1560   ...           573
# 955           1950         484           0        495   ...           492
# 1215          1966         180         374        340   ...           384
# 385           2005          24           0       1232   ...           430
# 805           2008           0           0       1417   ...           554
# 1437          2008        1336           0        596   ...           774
# 343           2005          28           0       1656   ...           564
# 769           2003        1416           0        234   ...           841
# 1332          1958         690           0        126   ...           288
# 130           1966         445           0        479   ...           487
# 871           1998         505           0        299   ...           523
# 1123          2008           0           0        698   ...             0
# 1396          1950         353         334         60   ...           572
# 87            2009           0           0        612   ...           528
# 330           1964          40         264       1424   ...           352
# 1238          2005           0           0       1141   ...           484
# 466           1970         778           0        499   ...           526
# 121           1950           0           0        732   ...           264
# 1044          1981        1104           0       1420   ...           542
# 1095          2006          24           0       1290   ...           440
# 1130          1950         622           0        500   ...           576
# 1294          1990         167           0        697   ...           572
# 860           1998           0           0        912   ...           216
# 1126          2007           0           0       1373   ...           660
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 135           98            0              0          0            0
# 1452           0           28              0          0            0
# 762          169           45              0          0            0
# 932            0          191              0          0            0
# 435          158           61              0          0            0
# 629          176            0              0          0            0
# 1210         635          104              0          0            0
# 1118         280           34              0          0            0
# 1084         315           44              0          0            0
# 158            0          136              0          0            0
# 967            0            0              0          0            0
# 1259         180            0              0          0           80
# 551            0            0              0          0            0
# 497            0          100              0          0            0
# 1031         136           63              0          0            0
# 1262         120            0              0          0            0
# 1013           0           30            226          0            0
# 1311         264           98              0          0            0
# 566          144           39              0          0            0
# 610          253          142              0          0            0
# 1278           0          211              0          0            0
# 1263           0            0            126          0            0
# 816            0            0            120          0            0
# 438            0            0             34          0            0
# 940           40            0              0          0            0
# 96           158           29              0          0            0
# 560            0            0              0          0           95
# 1182         171           78              0          0            0
# 471            0            0              0          0          276
# 1004         156            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 747          181            0            386          0            0
# 252          138           45              0          0            0
# 21             0            0            205          0            0
# 1337           0           20              0          0            0
# 459            0            0            248          0            0
# 1184           0          263              0          0          263
# 276          100          150              0          0            0
# 955            0            0              0          0            0
# 1215           0            0              0          0            0
# 385          146           20              0          0          144
# 805            0           60              0          0            0
# 1437           0           66              0        304            0
# 343          495           72              0          0            0
# 769          503           36              0          0          210
# 1332           0            0              0          0            0
# 130          105           66              0          0            0
# 871            0           77              0          0            0
# 1123           0          200              0          0            0
# 1396           0            0             50          0            0
# 87             0          234              0          0            0
# 330          155            0              0          0            0
# 1238           0            0              0          0            0
# 466            0            0              0          0          176
# 121            0            0            140          0            0
# 1044         474          120              0          0            0
# 1095           0           22              0          0            0
# 1130         431           44              0          0            0
# 1294           0            0              0          0            0
# 860            0          240              0          0            0
# 1126         143           20              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold
# 135          0        0       5    2008
# 1452         0        0       5    2006
# 762          0        0       6    2010
# 932          0        0       3    2007
# 435          0        0       4    2009
# 629          0        0       6    2008
# 1210         0      400       5    2010
# 1118         0        0      12    2008
# 1084         0        0       7    2006
# 158          0        0       5    2010
# 967          0        0       7    2008
# 1259         0        0       7    2008
# 551          0        0       6    2008
# 497          0        0       6    2008
# 1031         0        0       8    2009
# 1262         0        0      11    2009
# 1013         0        0       6    2009
# 1311         0        0       1    2007
# 566          0        0       6    2008
# 610          0        0       5    2009
# 1278         0        0       3    2008
# 1263         0        0       7    2007
# 816          0        0       7    2006
# 438          0        0       3    2007
# 940          0        0       7    2006
# 96           0        0       8    2006
# 560          0        0       5    2010
# 1182       555        0       7    2007
# 471          0        0      11    2007
# 1004         0        0       5    2009
# ...        ...      ...     ...     ...
# 747          0        0       5    2009
# 252          0        0      12    2008
# 21           0        0       6    2007
# 1337         0        0       3    2006
# 459          0        0       7    2009
# 1184         0        0       5    2007
# 276          0        0       4    2010
# 955          0        0       8    2007
# 1215         0        0       5    2007
# 385          0        0       4    2010
# 805          0        0       7    2008
# 1437         0        0      11    2008
# 343          0        0       7    2008
# 769          0        0       6    2010
# 1332         0        0       5    2009
# 130          0        0       5    2006
# 871          0        0       6    2010
# 1123         0        0       6    2009
# 1396         0        0       6    2010
# 87           0        0       6    2009
# 330          0        0      11    2007
# 1238         0        0       3    2006
# 466          0        0       4    2007
# 121          0        0       6    2007
# 1044         0        0       7    2009
# 1095         0        0       3    2007
# 1130         0        0      12    2009
# 1294         0        0       4    2006
# 860          0        0       6    2007
# 1126         0        0       6    2009
#
# [1022 rows x 34 columns]

# %%
null_columns=X_train.columns[X_train.isnull().any()] 
print(X_train[X_train.isnull().any(axis=1)][null_columns].head(100))
# X_train[X_train['Alley'].isnull()]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Vamos comparar se os índices são os mesmos, o resultado deve ser True
(X_train_ohc.index == X_train.index).all()
# Out:
# True

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

LR = LinearRegression()

# Lista para armazenar os erros das bases
error_df = list()

# Aplique .fit() na base de treino e predict na base de treino e teste
LR = LR.fit(X_train, y_train)
y_train_pred = LR.predict(X_train)
y_test_pred = LR.predict(X_test)

error_df.append(pd.Series({'train': mean_squared_error(y_train, y_train_pred),
                           'test' : mean_squared_error(y_test,  y_test_pred)},
                           name='no enc'))

# Repita para a base data_ohc
LR = LR.fit(X_train_ohc, y_train_ohc)
y_train_ohc_pred = LR.predict(X_train_ohc)
y_test_ohc_pred = LR.predict(X_test_ohc)

error_df.append(pd.Series({'train': mean_squared_error(y_train_ohc, y_train_ohc_pred),
                           'test' : mean_squared_error(y_test_ohc,  y_test_ohc_pred)},
                          name='one-hot enc'))

# Juntar os resultados em uma tabela
error_df = pd.concat(error_df, axis=1)
error_df
# Out:
#              no enc   one-hot enc
# train  1.211827e+09  3.610898e+08
# test   1.281872e+09  5.828511e+09
